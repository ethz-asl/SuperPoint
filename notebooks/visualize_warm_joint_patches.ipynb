# %%
import cv2
import numpy as np
from superpoint.datasets.patches_dataset import PatchesDataset
from utils import plot_imgs

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
config = {'dataset': 'warm_joint', 'truncate': 50, 'preprocessing': {'resize': False}}
dataset = PatchesDataset(**config)
data = dataset.get_test_set()

# %%
for i in range(10):
    d = next(data)
    image = np.concatenate([d['image'], d['image'], d['image']], axis=2) / 255.
    warped_image = np.concatenate([d['warped_image'], d['warped_image'], d['warped_image']], axis=2) / 255.
    plot_imgs([image, warped_image], titles=['original', 'patch'], dpi=200, cmap='gray')
